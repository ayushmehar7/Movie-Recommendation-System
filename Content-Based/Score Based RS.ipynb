# %% [markdown]
# ## Standard Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data Loading and Cleaning

# %%
movies = pd.read_csv("./movies_metadata.csv")

# %%
movies = movies['title genres runtime vote_average vote_count overview'.split()]
movies.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                               genres  runtime  vote_average  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     81.0           7.7
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    104.0           6.9
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...    101.0           6.5
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...    127.0           6.1
# 4                     [{'id': 35, 'name': 'Comedy'}]    106.0           5.7
#
#    vote_count                                           overview
# 0      5415.0  Led by Woody, Andy's toys live happily in his ...
# 1      2413.0  When siblings Judy and Peter discover an encha...
# 2        92.0  A family wedding reignites the ancient feud be...
# 3        34.0  Cheated on, mistreated and stepped on, the wom...
# 4       173.0  Just when George Banks has recovered from his ...

# %%
def clean_genres(x):
    gs = []
    x = x.strip("][").split(",")
    for l in range(1,len(x),2):
        y = x[l]
        gen = y.split(':')[1].split('}')[0].replace("'","").strip(" ")
        if gen.isalpha():
            gs.append(gen)
    return gs

# %%
movies['genres'] = movies['genres'].apply(clean_genres)

# %%
movies.head()
# Out:
#                          title                        genres  runtime  \
# 0                    Toy Story   [Animation, Comedy, Family]     81.0
# 1                      Jumanji  [Adventure, Fantasy, Family]    104.0
# 2             Grumpier Old Men             [Romance, Comedy]    101.0
# 3            Waiting to Exhale      [Comedy, Drama, Romance]    127.0
# 4  Father of the Bride Part II                      [Comedy]    106.0
#
#    vote_average  vote_count                                           overview
# 0           7.7      5415.0  Led by Woody, Andy's toys live happily in his ...
# 1           6.9      2413.0  When siblings Judy and Peter discover an encha...
# 2           6.5        92.0  A family wedding reignites the ancient feud be...
# 3           6.1        34.0  Cheated on, mistreated and stepped on, the wom...
# 4           5.7       173.0  Just when George Banks has recovered from his ...

# %% [markdown]
# We are not using any user information or any metrics in this notebook we are just displaying the top 20 percentile movies based on our custom ***Score***

# %%
m = movies['vote_count'].quantile(0.8)
movies = movies[(movies['runtime'] >= 45) & (movies['runtime'] <= 300)]

# %% [markdown]
# Separating movies having runtime between 45 and 300 minutes and having votes above 80 percentile

# %%
movies = movies[movies['vote_count'] >= m]

# %% [markdown]
# In addtion to above, we are using our own ***Score*** which takes into account the number of persons voted and what is their score.

# %% [markdown]
# <img src="Score_Equation.png">

# %% [markdown]
# In our case x = 80

# %%
C = movies['vote_average'].mean()
def score(x):
    v = x['vote_count']
    R = x['vote_average']
    return v/(v+m) * R + (m/(m+v)*C)

# %%
movies['score'] = movies.apply(score,axis = 1)

# %%
movies.head()
# Out:
#                          title                            genres  runtime  \
# 0                    Toy Story       [Animation, Comedy, Family]     81.0
# 1                      Jumanji      [Adventure, Fantasy, Family]    104.0
# 2             Grumpier Old Men                 [Romance, Comedy]    101.0
# 4  Father of the Bride Part II                          [Comedy]    106.0
# 5                         Heat  [Action, Crime, Drama, Thriller]    170.0
#
#    vote_average  vote_count  \
# 0           7.7      5415.0
# 1           6.9      2413.0
# 2           6.5        92.0
# 4           5.7       173.0
# 5           7.7      1886.0
#
#                                             overview     score
# 0  Led by Woody, Andy's toys live happily in his ...  7.687662
# 1  When siblings Judy and Peter discover an encha...  6.888865
# 2  A family wedding reignites the ancient feud be...  6.447711
# 4  Just when George Banks has recovered from his ...  5.846076
# 5  Obsessive master thief, Neil McCauley leads a ...  7.665173

# %%
movies.sort_values(by = 'score',axis = 0,ascending=False).head(50)
# Out:
#                                                title  \
# 10309                    Dilwale Dulhania Le Jayenge
# 314                         The Shawshank Redemption
# 834                                    The Godfather
# 40251                                     Your Name.
# 12481                                The Dark Knight
# 2843                                      Fight Club
# 292                                     Pulp Fiction
# 522                                 Schindler's List
